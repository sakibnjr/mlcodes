# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("raw.csv")
data
# Out:
#      S.NO       Submitted Time      What is your name?  Your age?  Gender?  \
# 0       1  2024-02-12 00:09:48     Esheta Ahamed Barno       22.0  Female
# 1       2  2024-02-12 00:33:04             Wahid Sadik       20.0     Male
# 2       3  2024-02-12 00:41:10  Atikur Rahman Majumder       20.0     Male
# 3       4  2024-02-12 01:02:42        Israt Jahan Ifti       20.0   Female
# 4       5  2024-02-12 01:47:21       Tasnia Naima Nova       20.0  Female
# ..    ...                  ...                     ...        ...      ...
# 97     98  2024-02-14 09:36:25            Nurjahan Mim       21.0  Female
# 98     99  2024-02-14 09:50:06       Asiful islam Abir       24.0     Male
# 99    100  2024-02-14 10:10:22     Mahmuda Akter Mukta       22.0  Female
# 100   101  2024-02-14 10:45:57  Md. Najmus Sakib Nahid       22.0     Male
# 101   102  2024-02-14 11:19:49      Arnob Kumar Mondal       20.0     Male
#
#     Your education level? Have you ever used e-learning platforms?  \
# 0                Bachelor                                      Yes
# 1                Bachelor                                      Yes
# 2                Bachelor                                      Yes
# 3                Bachelor                                      Yes
# 4                Bachelor                                      Yes
# ..                    ...                                      ...
# 97               Bachelor                                      Yes
# 98               Bachelor                                      Yes
# 99               Bachelor                                      Yes
# 100              Bachelor                                      Yes
# 101              Bachelor                                      Yes
#
#     Which e-learning platforms have you used?  \
# 0                                     Diu BLC
# 1                            Diu BLC | Udemy
# 2                            Diu BLC | Udemy
# 3                            Diu BLC | Udemy
# 4                                     Diu BLC
# ..                                        ...
# 97                                    Diu BLC
# 98                                    Diu BLC
# 99                                    Diu BLC
# 100             Diu BLC | Udemy  | Coursera
# 101                                   Diu BLC
#
#     Amount of time spent daily in online classes/hour  \
# 0                                         More than 5
# 1                                         More than 5
# 2                                                   3
# 3                                         More than 5
# 4                                         More than 5
# ..                                                ...
# 97                                                  4
# 98                                                  5
# 99                                                  4
# 100                                                 3
# 101                                                 4
#
#     What was your attendance score on online classes?  \
# 0                                             75-100%
# 1                                             75-100%
# 2                                              25-50%
# 3                                              25-50%
# 4                                              50-75%
# ..                                                ...
# 97                                             50-75%
# 98                                             50-75%
# 99                                            75-100%
# 100                                           75-100%
# 101                                           75-100%
#
#     I understood the topics that are conducted online.  \
# 0                                       Somewhat Agree
# 1                                                Agree
# 2                                       Somewhat Agree
# 3                                                Agree
# 4                                    Somewhat Disagree
# ..                                                 ...
# 97                                   Somewhat Disagree
# 98                                               Agree
# 99                                               Agree
# 100                                  Somewhat Disagree
# 101                                              Agree
#
#     How was your quiz score after taking online classes?  \
# 0                                                10-15
# 1                                                10-15
# 2                                                10-15
# 3                                                10-15
# 4                                                  0-5
# ..                                                 ...
# 97                                               10-15
# 98                                               10-15
# 99                                               10-15
# 100                                               5-10
# 101                                              10-15
#
#      Mark achieved in assignment. Mark achieved in the project.  \
# 0                               5                         10-20
# 1                               7                      below 10
# 2                               7                         10-20
# 3                               8                         20-25
# 4                               6                         10-20
# ..                            ...                           ...
# 97                              4                         10-20
# 98                              6                         20-25
# 99                              4                         10-20
# 100                             2                         10-20
# 101                             7                         10-20
#
#     Marks achieved in midterm exam. Tell us about your course result.  \
# 0                             20-25                              Good
# 1                             20-25                              Good
# 2                             20-25                              Good
# 3                             20-25                              Good
# 4                             20-25                      Satisfactory
# ..                              ...                               ...
# 97                            10-20                      Satisfactory
# 98                            10-20                              Poor
# 99                            20-25                      Satisfactory
# 100                           10-20                              Good
# 101                           20-25                      Satisfactory
#
#     Rate your user experience in e-learning platform.
# 0                                             Neutral
# 1                                             Neutral
# 2                                             Neutral
# 3                                             Neutral
# 4                                                Good
# ..                                                ...
# 97                                               Good
# 98                                              Worst
# 99                                               Good
# 100                                             Worst
# 101                                              Good
#
# [102 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['S.NO', 'Submitted Time', 'What is your name?', 'Your age?', 'Gender?',
#        'Your education level?', 'Have you ever used e-learning platforms?',
#        'Which e-learning platforms have you used?',
#        'Amount of time spent daily in online classes/hour',
#        'What was your attendance score on online classes?',
#        'I understood the topics that are conducted online.',
#        'How was your quiz score after taking online classes?',
#        'Mark achieved in assignment.', 'Mark achieved in the project.',
#        'Marks achieved in midterm exam.', 'Tell us about your course result.',
#        'Rate your user experience in e-learning platform.'],
#       dtype='object')

# %%
data.drop('Submitted Time', axis=1, inplace=True)

# %%
data.drop('What is your name?', axis=1, inplace=True)

# %%
data
# Out:
#      S.NO  Your age?  Gender? Your education level?  \
# 0       1       22.0  Female               Bachelor
# 1       2       20.0     Male              Bachelor
# 2       3       20.0     Male              Bachelor
# 3       4       20.0   Female              Bachelor
# 4       5       20.0  Female               Bachelor
# ..    ...        ...      ...                   ...
# 97     98       21.0  Female               Bachelor
# 98     99       24.0     Male              Bachelor
# 99    100       22.0  Female               Bachelor
# 100   101       22.0     Male              Bachelor
# 101   102       20.0     Male              Bachelor
#
#     Have you ever used e-learning platforms?  \
# 0                                        Yes
# 1                                        Yes
# 2                                        Yes
# 3                                        Yes
# 4                                        Yes
# ..                                       ...
# 97                                       Yes
# 98                                       Yes
# 99                                       Yes
# 100                                      Yes
# 101                                      Yes
#
#     Which e-learning platforms have you used?  \
# 0                                     Diu BLC
# 1                            Diu BLC | Udemy
# 2                            Diu BLC | Udemy
# 3                            Diu BLC | Udemy
# 4                                     Diu BLC
# ..                                        ...
# 97                                    Diu BLC
# 98                                    Diu BLC
# 99                                    Diu BLC
# 100             Diu BLC | Udemy  | Coursera
# 101                                   Diu BLC
#
#     Amount of time spent daily in online classes/hour  \
# 0                                         More than 5
# 1                                         More than 5
# 2                                                   3
# 3                                         More than 5
# 4                                         More than 5
# ..                                                ...
# 97                                                  4
# 98                                                  5
# 99                                                  4
# 100                                                 3
# 101                                                 4
#
#     What was your attendance score on online classes?  \
# 0                                             75-100%
# 1                                             75-100%
# 2                                              25-50%
# 3                                              25-50%
# 4                                              50-75%
# ..                                                ...
# 97                                             50-75%
# 98                                             50-75%
# 99                                            75-100%
# 100                                           75-100%
# 101                                           75-100%
#
#     I understood the topics that are conducted online.  \
# 0                                       Somewhat Agree
# 1                                                Agree
# 2                                       Somewhat Agree
# 3                                                Agree
# 4                                    Somewhat Disagree
# ..                                                 ...
# 97                                   Somewhat Disagree
# 98                                               Agree
# 99                                               Agree
# 100                                  Somewhat Disagree
# 101                                              Agree
#
#     How was your quiz score after taking online classes?  \
# 0                                                10-15
# 1                                                10-15
# 2                                                10-15
# 3                                                10-15
# 4                                                  0-5
# ..                                                 ...
# 97                                               10-15
# 98                                               10-15
# 99                                               10-15
# 100                                               5-10
# 101                                              10-15
#
#      Mark achieved in assignment. Mark achieved in the project.  \
# 0                               5                         10-20
# 1                               7                      below 10
# 2                               7                         10-20
# 3                               8                         20-25
# 4                               6                         10-20
# ..                            ...                           ...
# 97                              4                         10-20
# 98                              6                         20-25
# 99                              4                         10-20
# 100                             2                         10-20
# 101                             7                         10-20
#
#     Marks achieved in midterm exam. Tell us about your course result.  \
# 0                             20-25                              Good
# 1                             20-25                              Good
# 2                             20-25                              Good
# 3                             20-25                              Good
# 4                             20-25                      Satisfactory
# ..                              ...                               ...
# 97                            10-20                      Satisfactory
# 98                            10-20                              Poor
# 99                            20-25                      Satisfactory
# 100                           10-20                              Good
# 101                           20-25                      Satisfactory
#
#     Rate your user experience in e-learning platform.
# 0                                             Neutral
# 1                                             Neutral
# 2                                             Neutral
# 3                                             Neutral
# 4                                                Good
# ..                                                ...
# 97                                               Good
# 98                                              Worst
# 99                                               Good
# 100                                             Worst
# 101                                              Good
#
# [102 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# S.NO                                                     0
# Your age?                                               11
# Gender?                                                  0
# Your education level?                                    0
# Have you ever used e-learning platforms?                 0
# Which e-learning platforms have you used?                5
# Amount of time spent daily in online classes/hour        0
# What was your attendance score on online classes?        0
# I understood the topics that are conducted online.       0
# How was your quiz score after taking online classes?     0
# Mark achieved in assignment.                             0
# Mark achieved in the project.                            0
# Marks achieved in midterm exam.                          0
# Tell us about your course result.                        0
# Rate your user experience in e-learning platform.        0
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 15 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   S.NO                                                  102 non-null    int64
#  1   Your age?                                             91 non-null     float64
#  2   Gender?                                               102 non-null    object
#  3   Your education level?                                 102 non-null    object
#  4   Have you ever used e-learning platforms?              102 non-null    object
#  5   Which e-learning platforms have you used?             97 non-null     object
#  6   Amount of time spent daily in online classes/hour     102 non-null    object
#  7   What was your attendance score on online classes?     102 non-null    object
#  8   I understood the topics that are conducted online.    102 non-null    object
#  9   How was your quiz score after taking online classes?  102 non-null    object
#  10  Mark achieved in assignment.                          102 non-null    int64
#  11  Mark achieved in the project.                         102 non-null    object
#  12  Marks achieved in midterm exam.                       102 non-null    object
#  13  Tell us about your course result.                     102 non-null    object
#  14  Rate your user experience in e-learning platform.     102 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 12.1+ KB

# %%
data['Your age?']=data['Your age?'].fillna(data['Your age?'].mean())

# %%
data['Which e-learning platforms have you used?']=data['Which e-learning platforms have you used?'].fillna(data['Which e-learning platforms have you used?'].mode()[0])

# %%
data.isnull().sum()
# Out:
# S.NO                                                    0
# Your age?                                               0
# Gender?                                                 0
# Your education level?                                   0
# Have you ever used e-learning platforms?                0
# Which e-learning platforms have you used?               0
# Amount of time spent daily in online classes/hour       0
# What was your attendance score on online classes?       0
# I understood the topics that are conducted online.      0
# How was your quiz score after taking online classes?    0
# Mark achieved in assignment.                            0
# Mark achieved in the project.                           0
# Marks achieved in midterm exam.                         0
# Tell us about your course result.                       0
# Rate your user experience in e-learning platform.       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
categorical_columns = data.select_dtypes(include=['object']).columns
print(categorical_columns)
# Out:
# Index(['Gender?', 'Your education level?',
#        'Have you ever used e-learning platforms?',
#        'Which e-learning platforms have you used?',
#        'Amount of time spent daily in online classes/hour',
#        'What was your attendance score on online classes?',
#        'I understood the topics that are conducted online.',
#        'How was your quiz score after taking online classes?',
#        'Mark achieved in the project.', 'Marks achieved in midterm exam.',
#        'Tell us about your course result.',
#        'Rate your user experience in e-learning platform.'],
#       dtype='object')

# %%
label_encoders = {}

for col in categorical_columns:
    label_encoders[col] = LabelEncoder()
    data[col] = label_encoders[col].fit_transform(data[col])
data
# Out:
#      S.NO  Your age?  Gender?  Your education level?  \
# 0       1       22.0        1                      0
# 1       2       20.0        2                      0
# 2       3       20.0        2                      0
# 3       4       20.0        0                      0
# 4       5       20.0        1                      0
# ..    ...        ...      ...                    ...
# 97     98       21.0        1                      0
# 98     99       24.0        2                      0
# 99    100       22.0        1                      0
# 100   101       22.0        2                      0
# 101   102       20.0        2                      0
#
#      Have you ever used e-learning platforms?  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ..                                        ...
# 97                                          0
# 98                                          0
# 99                                          0
# 100                                         0
# 101                                         0
#
#      Which e-learning platforms have you used?  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            0
# ..                                         ...
# 97                                           0
# 98                                           0
# 99                                           0
# 100                                          3
# 101                                          0
#
#      Amount of time spent daily in online classes/hour  \
# 0                                                    5
# 1                                                    5
# 2                                                    2
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 97                                                   3
# 98                                                   4
# 99                                                   3
# 100                                                  2
# 101                                                  3
#
#      What was your attendance score on online classes?  \
# 0                                                    3
# 1                                                    3
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 97                                                   2
# 98                                                   2
# 99                                                   3
# 100                                                  3
# 101                                                  3
#
#      I understood the topics that are conducted online.  \
# 0                                                    3
# 1                                                    0
# 2                                                    3
# 3                                                    0
# 4                                                    4
# ..                                                 ...
# 97                                                   4
# 98                                                   0
# 99                                                   0
# 100                                                  4
# 101                                                  0
#
#      How was your quiz score after taking online classes?  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 97                                                   1
# 98                                                   1
# 99                                                   1
# 100                                                  2
# 101                                                  1
#
#      Mark achieved in assignment.  Mark achieved in the project.  \
# 0                               5                              0
# 1                               7                              2
# 2                               7                              0
# 3                               8                              1
# 4                               6                              0
# ..                            ...                            ...
# 97                              4                              0
# 98                              6                              1
# 99                              4                              0
# 100                             2                              0
# 101                             7                              0
#
#      Marks achieved in midterm exam.  Tell us about your course result.  \
# 0                                  1                                  0
# 1                                  1                                  0
# 2                                  1                                  0
# 3                                  1                                  0
# 4                                  1                                  2
# ..                               ...                                ...
# 97                                 0                                  2
# 98                                 0                                  1
# 99                                 1                                  2
# 100                                0                                  0
# 101                                1                                  2
#
#      Rate your user experience in e-learning platform.
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 97                                                   0
# 98                                                   4
# 99                                                   0
# 100                                                  4
# 101                                                  0
#
# [102 rows x 15 columns]

# %%
data.corr()
# Out:
#                                                         S.NO  Your age?  \
# S.NO                                                1.000000  -0.065864
# Your age?                                          -0.065864   1.000000
# Gender?                                            -0.031738   0.051676
# Your education level?                                    NaN        NaN
# Have you ever used e-learning platforms?                 NaN        NaN
# Which e-learning platforms have you used?           0.030309   0.067591
# Amount of time spent daily in online classes/hour  -0.181770  -0.103195
# What was your attendance score on online classes?   0.038925  -0.012838
# I understood the topics that are conducted online. -0.069240  -0.181368
# How was your quiz score after taking online cla...  0.098009  -0.175448
# Mark achieved in assignment.                       -0.167890   0.131323
# Mark achieved in the project.                      -0.069195  -0.032375
# Marks achieved in midterm exam.                     0.148102  -0.069062
# Tell us about your course result.                   0.081373   0.082041
# Rate your user experience in e-learning platform.   0.073357   0.019536
#
#                                                      Gender?  \
# S.NO                                               -0.031738
# Your age?                                           0.051676
# Gender?                                             1.000000
# Your education level?                                    NaN
# Have you ever used e-learning platforms?                 NaN
# Which e-learning platforms have you used?           0.080058
# Amount of time spent daily in online classes/hour   0.062354
# What was your attendance score on online classes?   0.032219
# I understood the topics that are conducted online.  0.013748
# How was your quiz score after taking online cla... -0.154707
# Mark achieved in assignment.                        0.007871
# Mark achieved in the project.                       0.194023
# Marks achieved in midterm exam.                    -0.001015
# Tell us about your course result.                  -0.147110
# Rate your user experience in e-learning platform.   0.019830
#
#                                                     Your education level?  \
# S.NO                                                                  NaN
# Your age?                                                             NaN
# Gender?                                                               NaN
# Your education level?                                                 NaN
# Have you ever used e-learning platforms?                              NaN
# Which e-learning platforms have you used?                             NaN
# Amount of time spent daily in online classes/hour                     NaN
# What was your attendance score on online classes?                     NaN
# I understood the topics that are conducted online.                    NaN
# How was your quiz score after taking online cla...                    NaN
# Mark achieved in assignment.                                          NaN
# Mark achieved in the project.                                         NaN
# Marks achieved in midterm exam.                                       NaN
# Tell us about your course result.                                     NaN
# Rate your user experience in e-learning platform.                     NaN
#
#                                                     Have you ever used e-learning platforms?  \
# S.NO                                                                                     NaN
# Your age?                                                                                NaN
# Gender?                                                                                  NaN
# Your education level?                                                                    NaN
# Have you ever used e-learning platforms?                                                 NaN
# Which e-learning platforms have you used?                                                NaN
# Amount of time spent daily in online classes/hour                                        NaN
# What was your attendance score on online classes?                                        NaN
# I understood the topics that are conducted online.                                       NaN
# How was your quiz score after taking online cla...                                       NaN
# Mark achieved in assignment.                                                             NaN
# Mark achieved in the project.                                                            NaN
# Marks achieved in midterm exam.                                                          NaN
# Tell us about your course result.                                                        NaN
# Rate your user experience in e-learning platform.                                        NaN
#
#                                                     Which e-learning platforms have you used?  \
# S.NO                                                                                 0.030309
# Your age?                                                                            0.067591
# Gender?                                                                              0.080058
# Your education level?                                                                     NaN
# Have you ever used e-learning platforms?                                                  NaN
# Which e-learning platforms have you used?                                            1.000000
# Amount of time spent daily in online classes/hour                                    0.027798
# What was your attendance score on online classes?                                    0.156204
# I understood the topics that are conducted online.                                   0.054968
# How was your quiz score after taking online cla...                                   0.270022
# Mark achieved in assignment.                                                         0.088373
# Mark achieved in the project.                                                       -0.020245
# Marks achieved in midterm exam.                                                     -0.038381
# Tell us about your course result.                                                   -0.004247
# Rate your user experience in e-learning platform.                                    0.039934
#
#                                                     Amount of time spent daily in online classes/hour  \
# S.NO                                                                                        -0.181770
# Your age?                                                                                   -0.103195
# Gender?                                                                                      0.062354
# Your education level?                                                                             NaN
# Have you ever used e-learning platforms?                                                          NaN
# Which e-learning platforms have you used?                                                    0.027798
# Amount of time spent daily in online classes/hour                                            1.000000
# What was your attendance score on online classes?                                           -0.154345
# I understood the topics that are conducted online.                                          -0.023340
# How was your quiz score after taking online cla...                                          -0.033855
# Mark achieved in assignment.                                                                 0.118344
# Mark achieved in the project.                                                                0.101472
# Marks achieved in midterm exam.                                                             -0.115626
# Tell us about your course result.                                                            0.002712
# Rate your user experience in e-learning platform.                                           -0.201771
#
#                                                     What was your attendance score on online classes?  \
# S.NO                                                                                         0.038925
# Your age?                                                                                   -0.012838
# Gender?                                                                                      0.032219
# Your education level?                                                                             NaN
# Have you ever used e-learning platforms?                                                          NaN
# Which e-learning platforms have you used?                                                    0.156204
# Amount of time spent daily in online classes/hour                                           -0.154345
# What was your attendance score on online classes?                                            1.000000
# I understood the topics that are conducted online.                                          -0.007377
# How was your quiz score after taking online cla...                                          -0.023060
# Mark achieved in assignment.                                                                -0.037270
# Mark achieved in the project.                                                                0.023157
# Marks achieved in midterm exam.                                                              0.107670
# Tell us about your course result.                                                           -0.022036
# Rate your user experience in e-learning platform.                                            0.082007
#
#                                                     I understood the topics that are conducted online.  \
# S.NO                                                                                        -0.069240
# Your age?                                                                                   -0.181368
# Gender?                                                                                      0.013748
# Your education level?                                                                             NaN
# Have you ever used e-learning platforms?                                                          NaN
# Which e-learning platforms have you used?                                                    0.054968
# Amount of time spent daily in online classes/hour                                           -0.023340
# What was your attendance score on online classes?                                           -0.007377
# I understood the topics that are conducted online.                                           1.000000
# How was your quiz score after taking online cla...                                           0.026388
# Mark achieved in assignment.                                                                -0.106149
# Mark achieved in the project.                                                                0.181435
# Marks achieved in midterm exam.                                                             -0.084206
# Tell us about your course result.                                                           -0.070400
# Rate your user experience in e-learning platform.                                            0.114941
#
#                                                     How was your quiz score after taking online classes?  \
# S.NO                                                                                         0.098009
# Your age?                                                                                   -0.175448
# Gender?                                                                                     -0.154707
# Your education level?                                                                             NaN
# Have you ever used e-learning platforms?                                                          NaN
# Which e-learning platforms have you used?                                                    0.270022
# Amount of time spent daily in online classes/hour                                           -0.033855
# What was your attendance score on online classes?                                           -0.023060
# I understood the topics that are conducted online.                                           0.026388
# How was your quiz score after taking online cla...                                           1.000000
# Mark achieved in assignment.                                                                -0.103825
# Mark achieved in the project.                                                                0.050459
# Marks achieved in midterm exam.                                                             -0.093301
# Tell us about your course result.                                                           -0.058329
# Rate your user experience in e-learning platform.                                            0.043465
#
#                                                     Mark achieved in assignment.  \
# S.NO                                                                   -0.167890
# Your age?                                                               0.131323
# Gender?                                                                 0.007871
# Your education level?                                                        NaN
# Have you ever used e-learning platforms?                                     NaN
# Which e-learning platforms have you used?                               0.088373
# Amount of time spent daily in online classes/hour                       0.118344
# What was your attendance score on online classes?                      -0.037270
# I understood the topics that are conducted online.                     -0.106149
# How was your quiz score after taking online cla...                     -0.103825
# Mark achieved in assignment.                                            1.000000
# Mark achieved in the project.                                           0.004766
# Marks achieved in midterm exam.                                         0.033051
# Tell us about your course result.                                      -0.031042
# Rate your user experience in e-learning platform.                      -0.068221
#
#                                                     Mark achieved in the project.  \
# S.NO                                                                    -0.069195
# Your age?                                                               -0.032375
# Gender?                                                                  0.194023
# Your education level?                                                         NaN
# Have you ever used e-learning platforms?                                      NaN
# Which e-learning platforms have you used?                               -0.020245
# Amount of time spent daily in online classes/hour                        0.101472
# What was your attendance score on online classes?                        0.023157
# I understood the topics that are conducted online.                       0.181435
# How was your quiz score after taking online cla...                       0.050459
# Mark achieved in assignment.                                             0.004766
# Mark achieved in the project.                                            1.000000
# Marks achieved in midterm exam.                                         -0.024035
# Tell us about your course result.                                       -0.010553
# Rate your user experience in e-learning platform.                        0.029180
#
#                                                     Marks achieved in midterm exam.  \
# S.NO                                                                       0.148102
# Your age?                                                                 -0.069062
# Gender?                                                                   -0.001015
# Your education level?                                                           NaN
# Have you ever used e-learning platforms?                                        NaN
# Which e-learning platforms have you used?                                 -0.038381
# Amount of time spent daily in online classes/hour                         -0.115626
# What was your attendance score on online classes?                          0.107670
# I understood the topics that are conducted online.                        -0.084206
# How was your quiz score after taking online cla...                        -0.093301
# Mark achieved in assignment.                                               0.033051
# Mark achieved in the project.                                             -0.024035
# Marks achieved in midterm exam.                                            1.000000
# Tell us about your course result.                                         -0.028624
# Rate your user experience in e-learning platform.                          0.212554
#
#                                                     Tell us about your course result.  \
# S.NO                                                                         0.081373
# Your age?                                                                    0.082041
# Gender?                                                                     -0.147110
# Your education level?                                                             NaN
# Have you ever used e-learning platforms?                                          NaN
# Which e-learning platforms have you used?                                   -0.004247
# Amount of time spent daily in online classes/hour                            0.002712
# What was your attendance score on online classes?                           -0.022036
# I understood the topics that are conducted online.                          -0.070400
# How was your quiz score after taking online cla...                          -0.058329
# Mark achieved in assignment.                                                -0.031042
# Mark achieved in the project.                                               -0.010553
# Marks achieved in midterm exam.                                             -0.028624
# Tell us about your course result.                                            1.000000
# Rate your user experience in e-learning platform.                           -0.260346
#
#                                                     Rate your user experience in e-learning platform.
# S.NO                                                                                         0.073357
# Your age?                                                                                    0.019536
# Gender?                                                                                      0.019830
# Your education level?                                                                             NaN
# Have you ever used e-learning platforms?                                                          NaN
# Which e-learning platforms have you used?                                                    0.039934
# Amount of time spent daily in online classes/hour                                           -0.201771
# What was your attendance score on online classes?                                            0.082007
# I understood the topics that are conducted online.                                           0.114941
# How was your quiz score after taking online cla...                                           0.043465
# Mark achieved in assignment.                                                                -0.068221
# Mark achieved in the project.                                                                0.029180
# Marks achieved in midterm exam.                                                              0.212554
# Tell us about your course result.                                                           -0.260346
# Rate your user experience in e-learning platform.                                            1.000000

# %%
corr_matrix=data.corr()

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['S.NO', 'Your age?', 'Gender?', 'Your education level?',
#        'Have you ever used e-learning platforms?',
#        'Which e-learning platforms have you used?',
#        'Amount of time spent daily in online classes/hour',
#        'What was your attendance score on online classes?',
#        'I understood the topics that are conducted online.',
#        'How was your quiz score after taking online classes?',
#        'Mark achieved in assignment.', 'Mark achieved in the project.',
#        'Marks achieved in midterm exam.', 'Tell us about your course result.',
#        'Rate your user experience in e-learning platform.'],
#       dtype='object')

# %%
# independentFeatures = ["3. You are a?", "4. How old are you?",
#        "5. You are from which department?",
#        "6. Which e-learning platforms have you used?",
#        "7. How frequently do you visit the e-learning platforms daily?",
#        "8. I don't understand the topics that are on e-learning platforms.",
#        "9. I understand the topics but need assistance for confusion clearing.",
#        "10. Completely understood the topic.",
#        "11. Please provide a rating from your user experience.",
#        "12. Have you ever used the generative AI tools for your study?",
#        "13. How often do you use generative AI for your tasks?",
#        "14. Using AI tools can reduce the time needed to complete various tasks (-is; assignments, reports, generating scripts)",
#        "15. How accurate do you think an AI-generated outcome can be?",
#        "16. How would you feel about using a combination of e-learning and generative AI for your studies?"]

# %%
independentFeatures = ['Your age?', 'Gender?', 'Your education level?',
       'Have you ever used e-learning platforms?',
       'Which e-learning platforms have you used?',
       'Amount of time spent daily in online classes/hour',
       'What was your attendance score on online classes?',
       'I understood the topics that are conducted online.',
       'How was your quiz score after taking online classes?',
       'Mark achieved in assignment.', 'Mark achieved in the project.',
       'Marks achieved in midterm exam.']

# %%
x = data[independentFeatures]

# %%
y = data['Tell us about your course result.']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
select = SelectKBest(score_func=chi2)

# %%
b_select=select.fit(x,y)

# %%
b_select.scores_
# Out:
# array([0.06833311, 0.45889641,        nan,        nan, 0.01338511,
#        0.28702368, 0.05716415, 2.92021455, 1.06708048, 0.24189785,
#        1.15155235, 0.91733927])

# %%
pd.DataFrame(b_select.scores_,columns=['Score'])
# Out:
#        Score
# 0   0.068333
# 1   0.458896
# 2        NaN
# 3        NaN
# 4   0.013385
# 5   0.287024
# 6   0.057164
# 7   2.920215
# 8   1.067080
# 9   0.241898
# 10  1.151552
# 11  0.917339

# %%
pd.DataFrame(x.columns)
# Out:
#                                                     0
# 0                                           Your age?
# 1                                             Gender?
# 2                               Your education level?
# 3            Have you ever used e-learning platforms?
# 4           Which e-learning platforms have you used?
# 5   Amount of time spent daily in online classes/hour
# 6   What was your attendance score on online classes?
# 7   I understood the topics that are conducted onl...
# 8   How was your quiz score after taking online cl...
# 9                        Mark achieved in assignment.
# 10                      Mark achieved in the project.
# 11                    Marks achieved in midterm exam.

# %%
c_score = pd.DataFrame(b_select.scores_,columns=['Score'])

# %%
c_col = pd.DataFrame(x.columns)

# %%
rank = pd.concat([c_col,c_score],axis=1)

# %%
rank.nlargest(5,'Score')
# Out:
#                                                     0     Score
# 7   I understood the topics that are conducted onl...  2.920215
# 10                      Mark achieved in the project.  1.151552
# 8   How was your quiz score after taking online cl...  1.067080
# 11                    Marks achieved in midterm exam.  0.917339
# 1                                             Gender?  0.458896

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2)

# %%
xinput = [
    'What was your attendance score on online classes?',
    'Mark achieved in the project.',
    'Marks achieved in midterm exam.',
    'How was your quiz score after taking online classes?',
    'Mark achieved in assignment.'
]

# %%
x = data[xinput]

# %%
y = data['Tell us about your course result.']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_classifier.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(xtest)

# %%
accuracy = accuracy_score(ytest, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3333333333333333

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(xtest)

from sklearn.metrics import accuracy_score

accuracy_score(ytest,y_pred)
# Out:
# 0.47619047619047616
