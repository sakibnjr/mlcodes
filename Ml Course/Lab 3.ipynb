# %%
import pandas as pd #dataset read,analyze, explore
import numpy as np #numerical, mathematical operation

# %%
import matplotlib.pyplot as plt #data visualization

# %%
x = [1,2,3,4,5]
y=[2,4,6,7,9]
#plt.plot(x,y)
plt.scatter(x,y)
plt.title("DIU CSE")
plt.xlabel("Class Size")
plt.ylabel("Student Size")
# Out:
# Text(0, 0.5, 'Student Size')

# %%
data = pd.read_csv("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.value_counts() #dataset er moddhe kotogula diff typer value ase
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)   female  38.0  1      0      PC 17599  71.2833   C85    C           1
# 572          1         1       Appleton, Mrs. Edward Dale (Charlotte Lamson)         female  53.0  2      0      11769     51.4792   C101   S           1
# 578          1         1       Silvey, Mrs. William Baird (Alice Munger)             female  39.0  1      0      13507     55.9000   E44    S           1
# 582          1         1       Thayer, Mrs. John Borland (Marian Longstreth Morris)  female  39.0  1      1      17421     110.8833  C68    C           1
# 584          0         1       Ross, Mr. John Hugo                                   male    36.0  0      0      13049     40.1250   A10    C           1
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = pd.read_csv("titanic.csv",usecols=["Age","Cabin","Embarked"]) #get particular column from a dataset
df
# Out:
#       Age Cabin Embarked
# 0    22.0   NaN        S
# 1    38.0   C85        C
# 2    26.0   NaN        S
# 3    35.0  C123        S
# 4    35.0   NaN        S
# ..    ...   ...      ...
# 886  27.0   NaN        S
# 887  19.0   B42        S
# 888   NaN   NaN        S
# 889  26.0  C148        C
# 890  32.0   NaN        Q
#
# [891 rows x 3 columns]

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
#df['Cabin'].mean()

# %%
df['Cabin'].median()

# %%
df['Cabin'].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %%
#df['Embarked'].mean()

# %%
#df['Embarked'].median()

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
def input_nan(df,variable,mean):
    df[variable+"_update"]=df[variable].fillna(mean)

# %%
mean = df['Age'].mean()

# %%
df
# Out:
#       Age Cabin Embarked  Age_update
# 0    22.0   NaN        S   22.000000
# 1    38.0   C85        C   38.000000
# 2    26.0   NaN        S   26.000000
# 3    35.0  C123        S   35.000000
# 4    35.0   NaN        S   35.000000
# ..    ...   ...      ...         ...
# 886  27.0   NaN        S   27.000000
# 887  19.0   B42        S   19.000000
# 888   NaN   NaN        S   29.699118
# 889  26.0  C148        C   26.000000
# 890  32.0   NaN        Q   32.000000
#
# [891 rows x 4 columns]

# %%
input_nan(df,"Age",mean)

# %%
df['Age_update'].mean()
# Out:
# 29.69911764705882

# %%
def updateEmbarked(df,variable,mode):
    df[variable+"_update"]=df[variable].fillna(mode)

# %%
mode = df['Embarked'].mode()

# %%
updateEmbarked(df,"Embarked",mode)

# %%
df
# Out:
#       Age Cabin Embarked  Age_update Embarked_update  Age_mode  Age_median
# 0    22.0   NaN        S   22.000000               S      22.0        22.0
# 1    38.0   C85        C   38.000000               C      38.0        38.0
# 2    26.0   NaN        S   26.000000               S      26.0        26.0
# 3    35.0  C123        S   35.000000               S      35.0        35.0
# 4    35.0   NaN        S   35.000000               S      35.0        35.0
# ..    ...   ...      ...         ...             ...       ...         ...
# 886  27.0   NaN        S   27.000000               S      27.0        27.0
# 887  19.0   B42        S   19.000000               S      19.0        19.0
# 888   NaN   NaN        S   29.699118               S      24.0        28.0
# 889  26.0  C148        C   26.000000               C      26.0        26.0
# 890  32.0   NaN        Q   32.000000               Q      32.0        32.0
#
# [891 rows x 7 columns]

# %%
def newAge(df,variable,mode):
    df[variable+"_mode"]=df[variable].fillna(mode)

# %%
def newAge2(df,variable,median):
    df[variable+"_median"]=df[variable].fillna(median)

# %%
mode = df['Age'].mode()
val = mode[0]
val
# Out:
# 24.0

# %%
median = df['Age'].median()
median
# Out:
# 28.0

# %%
newAge(df,"Age",val)

# %%
newAge2(df,"Age",median)

# %%
df
# Out:
#       Age Cabin Embarked  Age_update Embarked_update  Age_mode  Age_median
# 0    22.0   NaN        S   22.000000               S      22.0        22.0
# 1    38.0   C85        C   38.000000               C      38.0        38.0
# 2    26.0   NaN        S   26.000000               S      26.0        26.0
# 3    35.0  C123        S   35.000000               S      35.0        35.0
# 4    35.0   NaN        S   35.000000               S      35.0        35.0
# ..    ...   ...      ...         ...             ...       ...         ...
# 886  27.0   NaN        S   27.000000               S      27.0        27.0
# 887  19.0   B42        S   19.000000               S      19.0        19.0
# 888   NaN   NaN        S   29.699118               S      24.0        28.0
# 889  26.0  C148        C   26.000000               C      26.0        26.0
# 890  32.0   NaN        Q   32.000000               Q      32.0        32.0
#
# [891 rows x 7 columns]

# %%
df['Age_update'].isnull().sum()
# Out:
# 0

# %%
df['Age_mode'].isnull().sum()
# Out:
# 0

# %%
df['Age_median'].isnull().sum()
# Out:
# 0

# %%
df.describe() #to find outlier in dataset
# Out:
#               Age  Age_update    Age_mode  Age_median
# count  714.000000  891.000000  891.000000  891.000000
# mean    29.699118   29.699118   28.566970   29.361582
# std     14.526497   13.002015   13.199572   13.019697
# min      0.420000    0.420000    0.420000    0.420000
# 25%     20.125000   22.000000   22.000000   22.000000
# 50%     28.000000   29.699118   24.000000   28.000000
# 75%     38.000000   35.000000   35.000000   35.000000
# max     80.000000   80.000000   80.000000   80.000000

# %%
plt.boxplot(df.Age_mode) #non filled zero is outlier
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22c058dc4a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22c058dcb00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22c03c97650>],
#  'medians': [<matplotlib.lines.Line2D at 0x22c058dcd70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22c058dd340>],
#  'means': []}

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
df[df['Embarked'].isnull()]
# Out:
#       Age Cabin Embarked  Age_update Embarked_update  Age_mode  Age_median
# 61   38.0   B28      NaN        38.0             NaN      38.0        38.0
# 829  62.0   B28      NaN        62.0             NaN      62.0        62.0

# %%
df[df['Cabin'].isnull()]
# Out:
#       Age Cabin Embarked  Age_update Embarked_update  Age_mode  Age_median
# 0    22.0   NaN        S   22.000000               S      22.0        22.0
# 2    26.0   NaN        S   26.000000               S      26.0        26.0
# 4    35.0   NaN        S   35.000000               S      35.0        35.0
# 5     NaN   NaN        Q   29.699118               Q      24.0        28.0
# 7     2.0   NaN        S    2.000000               S       2.0         2.0
# ..    ...   ...      ...         ...             ...       ...         ...
# 884  25.0   NaN        S   25.000000               S      25.0        25.0
# 885  39.0   NaN        Q   39.000000               Q      39.0        39.0
# 886  27.0   NaN        S   27.000000               S      27.0        27.0
# 888   NaN   NaN        S   29.699118               S      24.0        28.0
# 890  32.0   NaN        Q   32.000000               Q      32.0        32.0
#
# [687 rows x 7 columns]

# %%
df[df['Age'].isnull()]
# Out:
#      Age Cabin Embarked  Age_update Embarked_update  Age_mode  Age_median
# 5    NaN   NaN        Q   29.699118               Q      24.0        28.0
# 17   NaN   NaN        S   29.699118               S      24.0        28.0
# 19   NaN   NaN        C   29.699118               C      24.0        28.0
# 26   NaN   NaN        C   29.699118               C      24.0        28.0
# 28   NaN   NaN        Q   29.699118               Q      24.0        28.0
# ..   ...   ...      ...         ...             ...       ...         ...
# 859  NaN   NaN        C   29.699118               C      24.0        28.0
# 863  NaN   NaN        S   29.699118               S      24.0        28.0
# 868  NaN   NaN        S   29.699118               S      24.0        28.0
# 878  NaN   NaN        S   29.699118               S      24.0        28.0
# 888  NaN   NaN        S   29.699118               S      24.0        28.0
#
# [177 rows x 7 columns]
