# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("abc.csv")
data
# Out:
#             Timestamp       What is your name?  What is your age?  \
# 0    12/24/2022 15:02    Ayesha Siraji Shejuty                 21
# 1    12/24/2022 15:08          Nushrah Ipshita                 18
# 2    12/24/2022 15:09        Nabhan Ezaz Ilhan                 18
# 3    12/24/2022 17:38     Rashedul Hoque Robin                 23
# 4    12/24/2022 17:50          Mubashira Hoque                 22
# ..                ...                      ...                ...
# 103  12/28/2022 23:06                Odry Khan                 25
# 104  12/28/2022 23:08     Mahmudul Hasan Sagor                 28
# 105  12/28/2022 23:09             Sejan Mahmud                 26
# 106  12/28/2022 23:17        Farhan Sakib Jesy                 28
# 107  12/28/2022 23:20  Sayyed Nishat Chowdhury                 24
#
#     What is your gender? A child should sleep?  \
# 0                 Female            8 to 9 hrs
# 1                 Female            8 to 9 hrs
# ...

# %%
data.drop('Timestamp', axis=1, inplace=True)

# %%
data
# Out:
#           What is your name?  What is your age? What is your gender?  \
# 0      Ayesha Siraji Shejuty                 21               Female
# 1            Nushrah Ipshita                 18               Female
# 2          Nabhan Ezaz Ilhan                 18                 Male
# 3       Rashedul Hoque Robin                 23                 Male
# 4            Mubashira Hoque                 22               Female
# ..                       ...                ...                  ...
# 103                Odry Khan                 25               Female
# 104     Mahmudul Hasan Sagor                 28                 Male
# 105             Sejan Mahmud                 26                 Male
# 106        Farhan Sakib Jesy                 28                 Male
# 107  Sayyed Nishat Chowdhury                 24                 Male
#
#     A child should sleep?  \
# 0              8 to 9 hrs
# 1              8 to 9 hrs
# 2              8 to 9 hrs
# 3              8 to 9 hrs
# ...

# %%
data.isnull().sum()
# Out:
# What is your name?                                                                                                                                    0
# What is your age?                                                                                                                                     0
# What is your gender?                                                                                                                                  0
# A child should sleep?                                                                                                                                 0
# At what ages do food allergies, iron deficiency and occur in children?                                                                                0
# During the early growing stage of a child the cause of malnutrition according to you is-                                                              0
# ...

# %%
data['What is your gender?'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='What is your gender?'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
one = le.fit_transform(data['At what ages do food allergies, iron deficiency and occur in children?'])
two = le.fit_transform(data['During the early growing stage of a child the cause of malnutrition according to you is-'])
three = two = le.fit_transform(data['Child nutrition can also effect by'])
four = two = le.fit_transform(data['During puberty most of the child need to take proper amount of nutrients because'])
five = two = le.fit_transform(data['The most common malnutrition of children in our country'])
six = two = le.fit_transform(data[''])
seven = two = le.fit_transform(data[''])
eight = two = le.fit_transform(data[''])
nine = two = le.fit_transform(data[''])

# %%
data['At what ages do food allergies, iron deficiency and occur in children?']=one
data['During the early growing stage of a child the cause of malnutrition according to you is-']=two
data['Child nutrition can also effect by']=three
data['During puberty most of the child need to take proper amount of nutrients because']=four
data['The most common malnutrition of children in our country']=five

# %%
data.drop('What is your name?', axis=1, inplace=True)

# %%
data.drop('What is your gender?', axis=1, inplace=True)

# %%
y=data['Child nutrition can also effect by']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
select = SelectKBest(score_func=chi2)

# %%
b_select=select.fit(x,y)

# %%
b_select.scores_

# %%
pd.DataFrame(b.select_scores_,columns=['Score'])

# %%
pd.DataFrame(x.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 pd.DataFrame(x.columns)
#
# NameError: name 'x' is not defined

# %%
c_score = pd.DataFrame(b.select_scores_,columns=['Score'])

# %%
c_col = pd.DataFrame(x.columns)

# %%
rank = pd.concat([c_col,c_score],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 rank = pd.concat([c_col,c_score],axis=1)
#
# NameError: name 'c_col' is not defined

# %%
rank.nlargest(5,'Score')
