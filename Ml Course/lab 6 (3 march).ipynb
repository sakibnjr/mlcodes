# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("abc.csv")
df
# Out:
#             Timestamp       What is your name?  What is your age?  \
# 0    12/24/2022 15:02    Ayesha Siraji Shejuty                 21
# 1    12/24/2022 15:08          Nushrah Ipshita                 18
# 2    12/24/2022 15:09        Nabhan Ezaz Ilhan                 18
# 3    12/24/2022 17:38     Rashedul Hoque Robin                 23
# 4    12/24/2022 17:50          Mubashira Hoque                 22
# ..                ...                      ...                ...
# 103  12/28/2022 23:06                Odry Khan                 25
# 104  12/28/2022 23:08     Mahmudul Hasan Sagor                 28
# 105  12/28/2022 23:09             Sejan Mahmud                 26
# 106  12/28/2022 23:17        Farhan Sakib Jesy                 28
# 107  12/28/2022 23:20  Sayyed Nishat Chowdhury                 24
#
#     What is your gender? A child should sleep?  \
# 0                 Female            8 to 9 hrs
# 1                 Female            8 to 9 hrs
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                                             0
# What is your name?                                                                                                                                    0
# What is your age?                                                                                                                                     0
# What is your gender?                                                                                                                                  0
# A child should sleep?                                                                                                                                 0
# At what ages do food allergies, iron deficiency and occur in children?                                                                                0
# ...

# %%
#df.drop("What is your name?", axis=1, inplace=True) #axix 1 = column, inplace = merge within same dataset
df
# Out:
#             Timestamp       What is your name?  What is your age?  \
# 0    12/24/2022 15:02    Ayesha Siraji Shejuty                 21
# 1    12/24/2022 15:08          Nushrah Ipshita                 18
# 2    12/24/2022 15:09        Nabhan Ezaz Ilhan                 18
# 3    12/24/2022 17:38     Rashedul Hoque Robin                 23
# 4    12/24/2022 17:50          Mubashira Hoque                 22
# ..                ...                      ...                ...
# 103  12/28/2022 23:06                Odry Khan                 25
# 104  12/28/2022 23:08     Mahmudul Hasan Sagor                 28
# 105  12/28/2022 23:09             Sejan Mahmud                 26
# 106  12/28/2022 23:17        Farhan Sakib Jesy                 28
# 107  12/28/2022 23:20  Sayyed Nishat Chowdhury                 24
#
#     What is your gender? A child should sleep?  \
# 0                 Female            8 to 9 hrs
# 1                 Female            8 to 9 hrs
# ...

# %%
df['What is your age?'].value_counts().plot(kind='bar') #value count -> kotogula data ase diff. type er,
# Out:
# <Axes: xlabel='What is your age?'>

# %%
df['What is your gender?'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='What is your gender?'>

# %%
df['A child should sleep?'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='A child should sleep?'>

# %%
df['A child should sleep?'].value_counts().plot(kind='kde', label='Child Sleep Org')
plt.legend()

# %%
df['At what ages do food allergies, iron deficiency and occur in children?'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='At what ages do food allergies, iron deficiency and occur in children?'>

# %%
df['During the early growing stage of a child the cause of malnutrition according to you is-'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='During the early growing stage of a child the cause of malnutrition according to you is-'>

# %%
df['Child nutrition can also effect by'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Child nutrition can also effect by'>

# %%
df['During puberty most of the child need to take proper amount of nutrients because'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='During puberty most of the child need to take proper amount of nutrients because'>

# %%
df['The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be'>

# %%
df['Do you prefer parental awareness in case of a sound health of a child'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Do you prefer parental awareness in case of a sound health of a child'>

# %%
df['Nutrition of a child related to'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Nutrition of a child related to'>

# %%
df['Diarrhea is a very common disease of infant. According to you it happens due to'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Diarrhea is a very common disease of infant. According to you it happens due to'>

# %%
df['Some people think that feeding a child more and more Can increase their body growth. But according to you it is a'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Some people think that feeding a child more and more Can increase their body growth. But according to you it is a'>

# %%
df['Whole grain foods such as breads, cereals that are high in Fibre'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Whole grain foods such as breads, cereals that are high in Fibre'>

# %%
df['Toddlers & preschoolers should have following nutrients in their diet'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Toddlers & preschoolers should have following nutrients in their diet'>

# %%
df.columns
# Out:
# Index(['Timestamp', 'What is your name?', 'What is your age?',
#        'What is your gender?', 'A child should sleep?',
#        'At what ages do food allergies, iron deficiency and occur in children?',
#        'During the early growing stage of a child the cause of malnutrition according to you is-',
#        'Child nutrition can also effect by',
#        'During puberty most of the child need to take proper amount of nutrients because',
#        'The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be',
#        'A girl child needs to have best care during puberty',
#        'The most common malnutrition of children in our country',
#        'Do you prefer parental awareness in case of a sound health of a child',
#        'Nutrition of a child related to',
#        'Diarrhea is a very common disease of infant. According to you it happens due to',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
one = le.fit_transform(df['What is your gender?'])

# %%
pd.DataFrame(one)
# Out:
#      0
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# ..  ..
# 103  0
# 104  1
# 105  1
# 106  1
# 107  1
#
# [108 rows x 1 columns]

# %%
two = le.fit_transform(df['What is your gender?'])

# %%
three = le.fit_transform(df['A child should sleep?'])

# %%
four = le.fit_transform(df['At what ages do food allergies, iron deficiency and occur in children?'])

# %%
five = le.fit_transform(df['During the early growing stage of a child the cause of malnutrition according to you is-'])

# %%
six = le.fit_transform(df['Child nutrition can also effect by'])

# %%
seven = le.fit_transform(df['During puberty most of the child need to take proper amount of nutrients because'])

# %%
eight = le.fit_transform(df['The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be'])

# %%
nine = le.fit_transform(df['A girl child needs to have best care during puberty'])

# %%
ten = le.fit_transform(df['The most common malnutrition of children in our country'])

# %%
eleven = le.fit_transform(df['Do you prefer parental awareness in case of a sound health of a child'])

# %%
t1 = le.fit_transform(df['Nutrition of a child related to'])

# %%
one = le.fit_transform(df['Diarrhea is a very common disease of infant. According to you it happens due to'])

# %%
one = le.fit_transform(df['Some people think that feeding a child more and more Can increase their body growth. But according to you it is a'])

# %%
one = le.fit_transform(df['Whole grain foods such as breads, cereals that are high in Fibre'])

# %%
one = le.fit_transform(df['WToddlers & preschoolers should have following nutrients in their diet'])

# %%
df.drop('Timestamp', axis=1, inplace=True)

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print(categorical_columns)
# Out:
# Index([], dtype='object')

# %%
label_encoders = {}

for col in categorical_columns:
    label_encoders[col] = LabelEncoder()
    df[col] = label_encoders[col].fit_transform(df[col])
df
# Out:
#      What is your name?  What is your age?  What is your gender?  \
# 0                    14                 21                     0
# 1                    69                 18                     0
# 2                    56                 18                     1
# 3                    74                 23                     1
# 4                    55                 22                     0
# ..                  ...                ...                   ...
# 103                  70                 25                     0
# 104                  45                 28                     1
# 105                  87                 26                     1
# 106                  33                 28                     1
# 107                  85                 24                     1
#
#      A child should sleep?  \
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        2
# ...

# %%
features = ["
A girl child needs to have best care during puberty",
"The most common malnutrition of children in our country",
"Diarrhea is a very common disease of infant. According to you it happens due to",
"During puberty most of the child need to take proper amount of nutrients because",
"During the early growing stage of a child the cause of malnutrition according to you is-",
"Some people think that feeding a child more and more Can increase their body growth. But according to you it is a"]

# %%
df.columns
# Out:
# Index(['What is your name?', 'What is your age?', 'What is your gender?',
#        'A child should sleep?',
#        'At what ages do food allergies, iron deficiency and occur in children?',
#        'During the early growing stage of a child the cause of malnutrition according to you is-',
#        'Child nutrition can also effect by',
#        'During puberty most of the child need to take proper amount of nutrients because',
#        'The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be',
#        'A girl child needs to have best care during puberty',
#        'The most common malnutrition of children in our country',
#        'Do you prefer parental awareness in case of a sound health of a child',
#        'Nutrition of a child related to',
#        'Diarrhea is a very common disease of infant. According to you it happens due to',
# ...

# %%
x = df[features]

# %%
y = df['Child nutrition can also effect by']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,y_pred)
# Out:
# 0.2727272727272727

# %%
#method process accuracy result      elicit website (add my project title here) minimum 10-12 project research paper
